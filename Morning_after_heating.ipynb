# %%
import os, sys, h5py, hdf5plugin, glob, numpy as np
from typing import List

try:
    import cupy as cp; xp, GPU = cp, True
    print("CuPy found – running on GPU")
except ImportError:
    import numpy as xp; GPU = False
    print("CuPy not found – falling back to NumPy (CPU)")

import napari
from magicgui import magicgui
from magicgui.widgets import Label, PushButton, LineEdit
from napari.qt.threading import thread_worker
from qtpy.QtCore    import Qt, QTimer
from qtpy.QtWidgets import (QApplication, QWidget, QListWidget,
                            QListWidgetItem, QSpinBox, QLabel,
                            QHBoxLayout, QVBoxLayout, QFileDialog)

def launch_viewer(root_dir, motors_file):
    root_dir = root_dir.rstrip('/') + '/'
    
    # Fix: Use proper glob pattern to find actual files
    scan_pattern = root_dir + "scan*/DEPow_0.000000_rockinglayer_10x_*_converted.h5"
    scan_files = sorted(glob.glob(scan_pattern))
    
    if not scan_files:
        raise RuntimeError(f"No scan files found matching pattern: {scan_pattern}")
    
    print(f"Found {len(scan_files)} scan files:")
    for f in scan_files[:3]:  # Print first 3 as preview
        print(f"  {f}")
    
    # Open the FIRST actual file found (not the pattern)
    with h5py.File(scan_files[0]) as f0:
        SCAN_COUNT, H, W = f0['scan_0/image/data'].shape

    with h5py.File(motors_file) as f:
        phi_vals = np.round(f['scan_0/instrument/positioners/diffry'][:], 4)
        chi_vals = np.round(f['scan_0/instrument/positioners/chi'][:], 4)

    PHI_COUNT = np.unique(phi_vals).size
    CHI_COUNT = np.unique(chi_vals).size

    def _frame(path: str, χ: int, φ: int) -> np.ndarray:
        χ = np.clip(χ, 0, CHI_COUNT-1)
        φ = np.clip(φ, 0, PHI_COUNT-1)
        g = φ*CHI_COUNT + χ
        with h5py.File(path) as f:
            return f['scan_0/image/data'][g]

    def _mean(path: str, χ0: int, φ0: int, χr: int, φr: int) -> np.ndarray:
        acc, cnt = None, 0
        for dχ in range(-χr, χr+1):
            for dφ in range(-φr, φr+1):
                f = _frame(path, χ0+dχ, φ0+dφ)
                acc = f if acc is None else acc + f
                cnt += 1
        return acc / cnt

    current_chi = 0
    current_phi = 42
    current_chi_rad = 0
    current_phi_rad = 0
    local_chi_off = np.zeros(len(scan_files), dtype=int)
    local_phi_off  = np.zeros(len(scan_files), dtype=int)
    slice_visible = np.ones(len(scan_files), dtype=bool)

    @thread_worker
    def _volume_worker(χ, φ, χr, φr, χoff, φoff, vis):
        vol = []
        for i, path in enumerate(scan_files):
            if not vis[i]:
                vol.append(np.zeros((H, W), dtype=np.float32)); continue
            eff_χ = χ + int(χoff[i])
            eff_φ = φ + int(φoff[i])
            vol.append(_mean(path, eff_χ, eff_φ, χr, φr))
        return np.log10(np.stack(vol).astype(np.float32))

    first_vol = _volume_worker.__wrapped__(
        current_chi, current_phi, current_chi_rad, current_phi_rad,
        local_chi_off, local_phi_off, slice_visible
    )
    vmin, vmax = float(first_vol.min()), float(first_vol.max())
    dz, dx, dy = 5.0, 0.15, 0.15

    viewer = napari.Viewer(title="DFXM volume (χ, φ)")
    vol_layer = viewer.add_image(
        first_vol, name='intensity', contrast_limits=(vmin, vmax),
        colormap='viridis', rendering='mip',
        iso_threshold=vmin + 0.25*(vmax - vmin), attenuation=0.01,
        scale=(dz, dy, dx)
    )
    chi_phi_label = Label()

    def _status():
        g = np.clip(current_phi,0,PHI_COUNT-1)*CHI_COUNT + np.clip(current_chi,0,CHI_COUNT-1)
        chi_phi_label.value = f"χ = {chi_vals[g]:.3f}°,   φ = {phi_vals[g]:.3f}°"
        viewer.status = f"χ‑idx {current_chi}, φ‑idx {current_phi} · "+chi_phi_label.value

    def _refresh():
        worker = _volume_worker(
            current_chi, current_phi, current_chi_rad, current_phi_rad,
            local_chi_off.copy(), local_phi_off.copy(), slice_visible.copy()
        )
        worker.returned.connect(lambda d: setattr(vol_layer, "data", d))
        worker.returned.connect(lambda _: _status())
        worker.start()

    @magicgui(χ_idx={'widget_type':'Slider','min':0,'max':CHI_COUNT-1,
                     'orientation':'horizontal','tracking':False},
              auto_call=True)
    def χ_slider(χ_idx: int = 0):
        nonlocal current_chi; current_chi = int(χ_idx); _refresh()

    @magicgui(φ_idx={'widget_type':'Slider','min':0,'max':PHI_COUNT-1,
                     'orientation':'horizontal','tracking':False},
              auto_call=True)
    def φ_slider(φ_idx: int = 0):
        nonlocal current_phi; current_phi = int(φ_idx); _refresh()

    @magicgui(χ_rad={'widget_type':'SpinBox','min':0,'max':CHI_COUNT//2},
              auto_call=True, layout='horizontal')
    def χ_comb(χ_rad: int = 0):
        nonlocal current_chi_rad; current_chi_rad = int(χ_rad); _refresh()

    @magicgui(φ_rad={'widget_type':'SpinBox','min':0,'max':PHI_COUNT//2},
              auto_call=True, layout='horizontal')
    def φ_comb(φ_rad: int = 0):
        nonlocal current_phi_rad; current_phi_rad = int(φ_rad); _refresh()

    gbox = QWidget(); g_lay = QVBoxLayout(gbox)
    for w in (χ_slider.native, φ_slider.native,
              χ_comb.native, φ_comb.native, chi_phi_label.native):
        g_lay.addWidget(w)

    class SliceCtrl(QWidget):
        def __init__(self):
            super().__init__()
            lay = QVBoxLayout(self)
            self.list = QListWidget()
            self.list.setSelectionMode(QListWidget.MultiSelection)
            for i in range(len(scan_files)):
                item = QListWidgetItem(f"z {i}")
                item.setFlags(item.flags() | Qt.ItemIsUserCheckable)
                item.setCheckState(Qt.Checked)
                self.list.addItem(item)
            lay.addWidget(self.list)

            rowχ = QHBoxLayout()
            rowχ.addWidget(QLabel("Δχ")); self.chi_sp = QSpinBox()
            self.chi_sp.setRange(-CHI_COUNT, CHI_COUNT); rowχ.addWidget(self.chi_sp)
            lay.addLayout(rowχ)

            rowφ = QHBoxLayout()
            rowφ.addWidget(QLabel("Δφ")); self.phi_sp = QSpinBox()
            self.phi_sp.setRange(-PHI_COUNT, PHI_COUNT); rowφ.addWidget(self.phi_sp)
            lay.addLayout(rowφ)

            self.list.itemSelectionChanged.connect(self._sync)
            self.list.itemChanged.connect(self._vis_change)
            self.chi_sp.valueChanged.connect(self._apply)
            self.phi_sp.valueChanged.connect(self._apply)

        def _rows(self): return [i.row() for i in self.list.selectedIndexes()]

        def _sync(self):
            if not self._rows(): return
            r = self._rows()[0]
            self.chi_sp.blockSignals(True); self.phi_sp.blockSignals(True)
            self.chi_sp.setValue(int(local_chi_off[r]))
            self.phi_sp.setValue(int(local_phi_off[r]))
            self.chi_sp.blockSignals(False); self.phi_sp.blockSignals(False)

        def _apply(self):
            for r in self._rows():
                local_chi_off[r] = self.chi_sp.value()
                local_phi_off[r]  = self.phi_sp.value()
            _refresh()

        def _vis_change(self, item):
            row = self.list.row(item)
            slice_visible[row] = (item.checkState()==Qt.Checked)
            _refresh()

    local_box = SliceCtrl()

    class FileBox(QWidget):
        def __init__(self):
            super().__init__()
            lay = QVBoxLayout(self)
            self.root_edit   = LineEdit(value=root_dir, label="Root folder")
            self.motor_edit  = LineEdit(value=motors_file, label="Motors .h5")
            browse_btn = PushButton(text="Browse folder…")
            motor_btn  = PushButton(text="Browse file…")
            apply_btn  = PushButton(text="Apply & Reload")

            row1 = QHBoxLayout(); row1.addWidget(self.root_edit.native)
            row1.addWidget(browse_btn.native); lay.addLayout(row1)
            row2 = QHBoxLayout(); row2.addWidget(self.motor_edit.native)
            row2.addWidget(motor_btn.native); lay.addLayout(row2)
            lay.addWidget(apply_btn.native)

            browse_btn.clicked.connect(self._pick_folder)
            motor_btn .clicked.connect(self._pick_file)
            apply_btn .clicked.connect(self._apply)

        def _pick_folder(self):
            d = QFileDialog.getExistingDirectory(self, "Select scan folder", root)
            if d: self.root_edit.value = d if d.endswith(os.sep) else d+os.sep

        def _pick_file(self):
            f, _ = QFileDialog.getOpenFileName(self, "Select motors HDF5",
                                               os.path.dirname(motors_file),
                                               "HDF5 files (*.h5)")
            if f: self.motor_edit.value = f

        def _apply(self):
            new_root  = self.root_edit.value
            new_motor = self.motor_edit.value
            viewer.close()
            QTimer.singleShot(0, lambda: launch_viewer(new_root, new_motor))

    file_box = FileBox()

    viewer.window.add_dock_widget(local_box,name="LOCAL slice tools", area="right")
    viewer.window.add_dock_widget(gbox,     name="GLOBAL controls", area="right")
    viewer.window.add_dock_widget(file_box, name="FILE handling", area="right")

    app = QApplication.instance()
    app.setStyleSheet(app.styleSheet()+"QLabeledSlider > QAbstractSpinBox {padding:0px 4px;}")

    _status()


    from napari_animation import Animation

    animation = Animation(viewer)

    viewer.dims.ndisplay = 3
    viewer.camera.angles = (0.0, 0.0, 90.0)
    animation.capture_keyframe()
    viewer.camera.zoom = 2.4
    animation.capture_keyframe()
    viewer.camera.angles = (-7.0, 15.7, 62.4)
    animation.capture_keyframe(steps=60)
    viewer.camera.angles = (2.0, -24.4, -36.7)
    animation.capture_keyframe(steps=60)
    viewer.reset_view()
    viewer.camera.angles = (0.0, 0.0, 90.0)
    animation.capture_keyframe()
    animation.animate('demo.mov', canvas_only=True)

    viewer.show()

if __name__ == "__main__":
    init_root   = "/Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/"
    init_motors = init_root + "DEPow_0.000000_rockinglayer_10x_00_converted.h5"
    launch_viewer(init_root, init_motors)
    napari.run()
# Out:
# CuPy not found – falling back to NumPy (CPU)
# Found 21 scan files:
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0000/DEPow_0.000000_rockinglayer_10x_00_converted.h5
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0001/DEPow_0.000000_rockinglayer_10x_01_converted.h5
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0002/DEPow_0.000000_rockinglayer_10x_02_converted.h5
# Rendering frames...
#   0%|          | 0/151 [00:00<?, ?it/s]IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1954, 1532) to (1968, 1536) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# 100%|██████████| 151/151 [00:11<00:00, 13.39it/s]
# 2025-12-29 10:15:26.567 Python[18791:27751491] not in fullscreen state

# %%
pip install napari-animation
# Out:
# Collecting napari-animation
#   Downloading napari_animation-0.0.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: imageio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (0.6.0)
# Requirement already satisfied: napari>=0.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (0.6.5)
# Requirement already satisfied: npe2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (0.7.9)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (2.2.6)
# Requirement already satisfied: qtpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (2.4.3)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (1.16.1)
# Requirement already satisfied: tqdm>=4.56.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (4.67.1)
# Requirement already satisfied: superqt in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-animation) (0.7.6)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (1.4.4)
# Requirement already satisfied: app-model<0.5.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.4.0)
# Requirement already satisfied: cachey>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.2.1)
# Requirement already satisfied: certifi>=2018.1.18 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (2025.8.3)
# Requirement already satisfied: dask>=2021.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dask[array]>=2021.10.0->napari>=0.5->napari-animation) (2025.9.1)
# Requirement already satisfied: jsonschema>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (4.25.1)
# Requirement already satisfied: lazy_loader>=0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.4)
# Requirement already satisfied: magicgui>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.10.1)
# Requirement already satisfied: napari-console>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.1.3)
# Requirement already satisfied: napari-plugin-engine>=0.1.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.2.0)
# Requirement already satisfied: napari-svg>=0.1.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.2.1)
# Requirement already satisfied: numpydoc>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (1.9.0)
# Requirement already satisfied: pandas>=1.3.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (2.3.3)
# Requirement already satisfied: Pillow>=9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (11.3.0)
# Requirement already satisfied: pint>=0.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.25)
# Requirement already satisfied: psutil>=5.9.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from napari>=0.5->napari-animation) (7.0.0)
# Requirement already satisfied: psygnal>=0.14.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.14.2)
# Requirement already satisfied: pydantic>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (2.11.10)
# Requirement already satisfied: pygments>=2.6.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from napari>=0.5->napari-animation) (2.19.2)
# Requirement already satisfied: PyOpenGL>=3.1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (3.1.10)
# Requirement already satisfied: PyYAML>=6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (6.0.2)
# Requirement already satisfied: scikit-image>=0.19.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (0.25.2)
# Requirement already satisfied: tifffile>=2022.7.28 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (2025.10.4)
# Requirement already satisfied: toolz>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.12 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (4.15.0)
# Requirement already satisfied: vispy<0.16,>=0.15.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (0.15.2)
# Requirement already satisfied: wrapt>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari>=0.5->napari-animation) (1.17.3)
# Requirement already satisfied: in-n-out>=0.1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from app-model<0.5.0,>=0.4.0->napari>=0.5->napari-animation) (0.2.1)
# Requirement already satisfied: pydantic-compat>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from app-model<0.5.0,>=0.4.0->napari>=0.5->napari-animation) (0.1.2)
# Requirement already satisfied: freetype-py in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from vispy<0.16,>=0.15.2->napari>=0.5->napari-animation) (2.5.1)
# Requirement already satisfied: hsluv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from vispy<0.16,>=0.15.2->napari>=0.5->napari-animation) (5.0.4)
# Requirement already satisfied: kiwisolver in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from vispy<0.16,>=0.15.2->napari>=0.5->napari-animation) (1.4.9)
# Requirement already satisfied: packaging in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from vispy<0.16,>=0.15.2->napari>=0.5->napari-animation) (25.0)
# Requirement already satisfied: heapdict in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cachey>=0.2.1->napari>=0.5->napari-animation) (1.0.1)
# Requirement already satisfied: click>=8.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.5->napari-animation) (8.3.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.5->napari-animation) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.5->napari-animation) (2025.9.0)
# Requirement already satisfied: partd>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.5->napari-animation) (1.4.2)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.2.0->napari>=0.5->napari-animation) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.2.0->napari>=0.5->napari-animation) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.2.0->napari>=0.5->napari-animation) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.2.0->napari>=0.5->napari-animation) (0.27.1)
# Requirement already satisfied: docstring-parser>=0.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from magicgui>=0.7.0->napari>=0.5->napari-animation) (0.17.0)
# Requirement already satisfied: IPython>=7.7.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from napari-console>=0.1.1->napari>=0.5->napari-animation) (9.5.0)
# Requirement already satisfied: ipykernel>=5.2.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from napari-console>=0.1.1->napari>=0.5->napari-animation) (6.30.1)
# Requirement already satisfied: qtconsole!=4.7.6,!=5.4.2,>=4.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from napari-console>=0.1.1->napari>=0.5->napari-animation) (5.7.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (5.14.3)
# Requirement already satisfied: decorator in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (3.0.52)
# Requirement already satisfied: stack_data in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from jupyter-client>=8.0.0->ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (4.4.0)
# Requirement already satisfied: build>=1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from npe2->napari-animation) (1.3.0)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from npe2->napari-animation) (14.1.0)
# Requirement already satisfied: tomli-w in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from npe2->napari-animation) (1.2.0)
# Requirement already satisfied: typer in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from npe2->napari-animation) (0.19.2)
# Requirement already satisfied: pyproject_hooks in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from build>=1->npe2->napari-animation) (1.2.0)
# Requirement already satisfied: sphinx>=6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from numpydoc>=1.0.0->napari>=0.5->napari-animation) (8.2.3)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.3.3->napari>=0.5->napari-animation) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.3.3->napari>=0.5->napari-animation) (2025.2)
# Requirement already satisfied: locket in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from partd>=1.4.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.5->napari-animation) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.7.0)
# Requirement already satisfied: flexcache>=0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pint>=0.17->napari>=0.5->napari-animation) (0.3)
# Requirement already satisfied: flexparser>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pint>=0.17->napari>=0.5->napari-animation) (0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.2.0->napari>=0.5->napari-animation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.2.0->napari>=0.5->napari-animation) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.2.0->napari>=0.5->napari-animation) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-image>=0.19.1->scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (3.5)
# Requirement already satisfied: pooch>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (1.8.2)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.5->napari-animation) (2.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (3.1.6)
# Requirement already satisfied: docutils<0.22,>=0.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from Jinja2>=3.1->sphinx>=6->numpydoc>=1.0.0->napari>=0.5->napari-animation) (3.0.2)
# Requirement already satisfied: pyconify>=0.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from superqt[iconify]>=0.7.2->magicgui>=0.7.0->napari>=0.5->napari-animation) (0.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich->npe2->napari-animation) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->npe2->napari-animation) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.5->napari-animation) (0.2.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer->npe2->napari-animation) (1.5.4)
# Downloading napari_animation-0.0.9-py3-none-any.whl (35 kB)
# Installing collected packages: napari-animation
# Successfully installed napari-animation-0.0.9
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imageio-ffmpeg
# Out:
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 25.0 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.6.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, sys, h5py, hdf5plugin, glob, numpy as np
from typing import List

try:
    import cupy as cp; xp, GPU = cp, True
    print("CuPy found – running on GPU")
except ImportError:
    import numpy as xp; GPU = False
    print("CuPy not found – falling back to NumPy (CPU)")

import napari
from magicgui import magicgui
from magicgui.widgets import Label, PushButton, LineEdit
from napari.qt.threading import thread_worker
from qtpy.QtCore    import Qt, QTimer
from qtpy.QtWidgets import (QApplication, QWidget, QListWidget,
                            QListWidgetItem, QSpinBox, QLabel,
                            QHBoxLayout, QVBoxLayout, QFileDialog)
from vispy import scene
from vispy.io import write_png
import imageio

def launch_viewer(root_dir, motors_file):
    root_dir = root_dir.rstrip('/') + '/'
    
    # Create output folder if it doesn't exist
    output_dir = os.path.join(root_dir, "output")
    os.makedirs(output_dir, exist_ok=True)
    
    # Fix: Use proper glob pattern to find actual files
    scan_pattern = root_dir + "scan*/DEPow_0.000000_rockinglayer_10x_*_converted.h5"
    scan_files = sorted(glob.glob(scan_pattern))
    
    if not scan_files:
        raise RuntimeError(f"No scan files found matching pattern: {scan_pattern}")
    
    print(f"Found {len(scan_files)} scan files:")
    for f in scan_files[:3]:  # Print first 3 as preview
        print(f"  {f}")
    
    # Open the FIRST actual file found (not the pattern)
    with h5py.File(scan_files[0]) as f0:
        SCAN_COUNT, H, W = f0['scan_0/image/data'].shape

    with h5py.File(motors_file) as f:
        phi_vals = np.round(f['scan_0/instrument/positioners/diffry'][:], 4)
        chi_vals = np.round(f['scan_0/instrument/positioners/chi'][:], 4)

    PHI_COUNT = np.unique(phi_vals).size
    CHI_COUNT = np.unique(chi_vals).size

    def _frame(path: str, χ: int, φ: int) -> np.ndarray:
        χ = np.clip(χ, 0, CHI_COUNT-1)
        φ = np.clip(φ, 0, PHI_COUNT-1)
        g = φ*CHI_COUNT + χ
        with h5py.File(path) as f:
            return f['scan_0/image/data'][g]

    def _mean(path: str, χ0: int, φ0: int, χr: int, φr: int) -> np.ndarray:
        acc, cnt = None, 0
        for dχ in range(-χr, χr+1):
            for dφ in range(-φr, φr+1):
                f = _frame(path, χ0+dχ, φ0+dφ)
                acc = f if acc is None else acc + f
                cnt += 1
        return acc / cnt

    current_chi = 0
    current_phi = 0
    current_chi_rad = 0
    current_phi_rad = 0
    local_chi_off = np.zeros(len(scan_files), dtype=int)
    local_phi_off  = np.zeros(len(scan_files), dtype=int)
    slice_visible = np.ones(len(scan_files), dtype=bool)

    @thread_worker
    def _volume_worker(χ, φ, χr, φr, χoff, φoff, vis):
        vol = []
        for i, path in enumerate(scan_files):
            if not vis[i]:
                vol.append(np.zeros((H, W), dtype=np.float32)); continue
            eff_χ = χ + int(χoff[i])
            eff_φ = φ + int(φoff[i])
            vol.append(_mean(path, eff_χ, eff_φ, χr, φr))
        return np.log10(np.stack(vol).astype(np.float32))

    first_vol = _volume_worker.__wrapped__(
        current_chi, current_phi, current_chi_rad, current_phi_rad,
        local_chi_off, local_phi_off, slice_visible
    )
    vmin, vmax = float(first_vol.min()), float(first_vol.max())
    dz, dx, dy = 5.0, 0.15, 0.15

    viewer = napari.Viewer(title="DFXM volume (χ, φ)")
    vol_layer = viewer.add_image(
        first_vol, name='intensity', contrast_limits=(vmin, vmax),
        colormap='viridis', rendering='iso',
        iso_threshold=vmin + 0.25*(vmax - vmin), attenuation=0.01,
        scale=(dz, dy, dx)
    )
    chi_phi_label = Label()

    def _status():
        g = np.clip(current_phi,0,PHI_COUNT-1)*CHI_COUNT + np.clip(current_chi,0,CHI_COUNT-1)
        chi_phi_label.value = f"χ = {chi_vals[g]:.3f}°,   φ = {phi_vals[g]:.3f}°"
        viewer.status = f"χ‑idx {current_chi}, φ‑idx {current_phi} · "+chi_phi_label.value

    def _refresh():
        worker = _volume_worker(
            current_chi, current_phi, current_chi_rad, current_phi_rad,
            local_chi_off.copy(), local_phi_off.copy(), slice_visible.copy()
        )
        worker.returned.connect(lambda d: setattr(vol_layer, "data", d))
        worker.returned.connect(lambda _: _status())
        worker.start()

    @magicgui(χ_idx={'widget_type':'Slider','min':0,'max':CHI_COUNT-1,
                     'orientation':'horizontal','tracking':False},
              auto_call=True)
    def χ_slider(χ_idx: int = 0):
        nonlocal current_chi; current_chi = int(χ_idx); _refresh()

    @magicgui(φ_idx={'widget_type':'Slider','min':0,'max':PHI_COUNT-1,
                     'orientation':'horizontal','tracking':False},
              auto_call=True)
    def φ_slider(φ_idx: int = 0):
        nonlocal current_phi; current_phi = int(φ_idx); _refresh()

    @magicgui(χ_rad={'widget_type':'SpinBox','min':0,'max':CHI_COUNT//2},
              auto_call=True, layout='horizontal')
    def χ_comb(χ_rad: int = 0):
        nonlocal current_chi_rad; current_chi_rad = int(χ_rad); _refresh()

    @magicgui(φ_rad={'widget_type':'SpinBox','min':0,'max':PHI_COUNT//2},
              auto_call=True, layout='horizontal')
    def φ_comb(φ_rad: int = 0):
        nonlocal current_phi_rad; current_phi_rad = int(φ_rad); _refresh()

    gbox = QWidget(); g_lay = QVBoxLayout(gbox)
    for w in (χ_slider.native, φ_slider.native,
              χ_comb.native, φ_comb.native, chi_phi_label.native):
        g_lay.addWidget(w)

    class SliceCtrl(QWidget):
        def __init__(self):
            super().__init__()
            lay = QVBoxLayout(self)
            self.list = QListWidget()
            self.list.setSelectionMode(QListWidget.MultiSelection)
            for i in range(len(scan_files)):
                item = QListWidgetItem(f"z {i}")
                item.setFlags(item.flags() | Qt.ItemIsUserCheckable)
                item.setCheckState(Qt.Checked)
                self.list.addItem(item)
            lay.addWidget(self.list)

            rowχ = QHBoxLayout()
            rowχ.addWidget(QLabel("Δχ")); self.chi_sp = QSpinBox()
            self.chi_sp.setRange(-CHI_COUNT, CHI_COUNT); rowχ.addWidget(self.chi_sp)
            lay.addLayout(rowχ)

            rowφ = QHBoxLayout()
            rowφ.addWidget(QLabel("Δφ")); self.phi_sp = QSpinBox()
            self.phi_sp.setRange(-PHI_COUNT, PHI_COUNT); rowφ.addWidget(self.phi_sp)
            lay.addLayout(rowφ)

            self.list.itemSelectionChanged.connect(self._sync)
            self.list.itemChanged.connect(self._vis_change)
            self.chi_sp.valueChanged.connect(self._apply)
            self.phi_sp.valueChanged.connect(self._apply)

        def _rows(self): return [i.row() for i in self.list.selectedIndexes()]

        def _sync(self):
            if not self._rows(): return
            r = self._rows()[0]
            self.chi_sp.blockSignals(True); self.phi_sp.blockSignals(True)
            self.chi_sp.setValue(int(local_chi_off[r]))
            self.phi_sp.setValue(int(local_phi_off[r]))
            self.chi_sp.blockSignals(False); self.phi_sp.blockSignals(False)

        def _apply(self):
            for r in self._rows():
                local_chi_off[r] = self.chi_sp.value()
                local_phi_off[r]  = self.phi_sp.value()
            _refresh()

        def _vis_change(self, item):
            row = self.list.row(item)
            slice_visible[row] = (item.checkState()==Qt.Checked)
            _refresh()

    local_box = SliceCtrl()

    class MovieBox(QWidget):
        """Widget for creating rotating movies"""
        def __init__(self):
            super().__init__()
            lay = QVBoxLayout(self)
            
            lay.addWidget(QLabel("<b>Movie Creation</b>"))
            
            # Number of frames
            frames_row = QHBoxLayout()
            frames_row.addWidget(QLabel("Frames:"))
            self.frames_sp = QSpinBox()
            self.frames_sp.setRange(10, 500)
            self.frames_sp.setValue(120)
            frames_row.addWidget(self.frames_sp)
            lay.addLayout(frames_row)
            
            # FPS
            fps_row = QHBoxLayout()
            fps_row.addWidget(QLabel("FPS:"))
            self.fps_sp = QSpinBox()
            self.fps_sp.setRange(5, 60)
            self.fps_sp.setValue(30)
            fps_row.addWidget(self.fps_sp)
            lay.addLayout(fps_row)
            
            # Image size
            size_row = QHBoxLayout()
            size_row.addWidget(QLabel("Width:"))
            self.width_sp = QSpinBox()
            self.width_sp.setRange(400, 3840)
            self.width_sp.setValue(1920)
            self.width_sp.setSingleStep(100)
            size_row.addWidget(self.width_sp)
            
            size_row.addWidget(QLabel("Height:"))
            self.height_sp = QSpinBox()
            self.height_sp.setRange(400, 2160)
            self.height_sp.setValue(1080)
            self.height_sp.setSingleStep(100)
            size_row.addWidget(self.height_sp)
            lay.addLayout(size_row)
            
            # Create buttons for different rotations
            self.z_btn = PushButton(text="Create Z-axis rotation")
            self.y_btn = PushButton(text="Create Y-axis rotation")
            self.zy_btn = PushButton(text="Create Z+Y rotation")
            
            lay.addWidget(self.z_btn.native)
            lay.addWidget(self.y_btn.native)
            lay.addWidget(self.zy_btn.native)
            
            self.status_label = QLabel("")
            lay.addWidget(self.status_label)
            
            self.z_btn.clicked.connect(lambda: self._create_movie('z'))
            self.y_btn.clicked.connect(lambda: self._create_movie('y'))
            self.zy_btn.clicked.connect(lambda: self._create_movie('zy'))
        
        def _create_movie(self, rotation_type):
            """Create rotating movie"""
            n_frames = self.frames_sp.value()
            fps = self.fps_sp.value()
            width = self.width_sp.value()
            height = self.height_sp.value()
            
            self.status_label.setText("Rendering movie...")
            QApplication.processEvents()
            
            # Get current camera state
            camera = viewer.camera
            initial_angles = camera.angles
            initial_center = camera.center
            
            frames = []
            
            for i in range(n_frames):
                if rotation_type == 'z':
                    # Rotate around Z-axis
                    angle_z = 360 * i / n_frames
                    camera.angles = (initial_angles[0], angle_z, initial_angles[2])
                    
                elif rotation_type == 'y':
                    # Rotate around Y-axis
                    angle_y = 360 * i / n_frames
                    camera.angles = (angle_y, initial_angles[1], initial_angles[2])
                    
                elif rotation_type == 'zy':
                    # Rotate around both Z and Y axes
                    angle_z = 360 * i / n_frames
                    angle_y = 180 * np.sin(2 * np.pi * i / n_frames)
                    camera.angles = (angle_y, angle_z, initial_angles[2])
                
                # Force update
                viewer.window._qt_window.update()
                QApplication.processEvents()
                
                # Capture frame
                screenshot = viewer.screenshot(canvas_only=True, size=(width, height))
                frames.append(screenshot)
                
                # Update status
                self.status_label.setText(f"Rendering: {i+1}/{n_frames}")
                QApplication.processEvents()
            
            # Reset camera
            camera.angles = initial_angles
            
            # Save movie
            timestamp = np.datetime64('now').astype(str).replace(':', '-').replace('.', '-')
            output_path = os.path.join(output_dir, f"rotation_{rotation_type}_{timestamp}.mp4")
            
            self.status_label.setText("Encoding video...")
            QApplication.processEvents()
            
            try:
                imageio.mimsave(output_path, frames, fps=fps, codec='libx264', quality=8)
                self.status_label.setText(f"✓ Saved: {os.path.basename(output_path)}")
                print(f"Movie saved to: {output_path}")
            except Exception as e:
                self.status_label.setText(f"✗ Error: {str(e)}")
                print(f"Error saving movie: {e}")

    movie_box = MovieBox()

    class FileBox(QWidget):
        def __init__(self):
            super().__init__()
            lay = QVBoxLayout(self)
            self.root_edit   = LineEdit(value=root_dir, label="Root folder")
            self.motor_edit  = LineEdit(value=motors_file, label="Motors .h5")
            browse_btn = PushButton(text="Browse folder…")
            motor_btn  = PushButton(text="Browse file…")
            apply_btn  = PushButton(text="Apply & Reload")

            row1 = QHBoxLayout(); row1.addWidget(self.root_edit.native)
            row1.addWidget(browse_btn.native); lay.addLayout(row1)
            row2 = QHBoxLayout(); row2.addWidget(self.motor_edit.native)
            row2.addWidget(motor_btn.native); lay.addLayout(row2)
            lay.addWidget(apply_btn.native)

            browse_btn.clicked.connect(self._pick_folder)
            motor_btn .clicked.connect(self._pick_file)
            apply_btn .clicked.connect(self._apply)

        def _pick_folder(self):
            d = QFileDialog.getExistingDirectory(self, "Select scan folder", root_dir)
            if d: self.root_edit.value = d if d.endswith(os.sep) else d+os.sep

        def _pick_file(self):
            f, _ = QFileDialog.getOpenFileName(self, "Select motors HDF5",
                                               os.path.dirname(motors_file),
                                               "HDF5 files (*.h5)")
            if f: self.motor_edit.value = f

        def _apply(self):
            new_root  = self.root_edit.value
            new_motor = self.motor_edit.value
            viewer.close()
            QTimer.singleShot(0, lambda: launch_viewer(new_root, new_motor))

    file_box = FileBox()

    viewer.window.add_dock_widget(local_box,name="LOCAL slice tools", area="right")
    viewer.window.add_dock_widget(gbox,     name="GLOBAL controls", area="right")
    viewer.window.add_dock_widget(movie_box, name="MOVIE creation", area="right")
    viewer.window.add_dock_widget(file_box, name="FILE handling", area="right")

    app = QApplication.instance()
    app.setStyleSheet(app.styleSheet()+"QLabeledSlider > QAbstractSpinBox {padding:0px 4px;}")

    _status()
    viewer.show()

if __name__ == "__main__":
    init_root   = "/Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/"
    init_motors = init_root + "DEPow_0.000000_rockinglayer_10x_00_converted.h5"
    launch_viewer(init_root, init_motors)
    napari.run()
# Out:
# CuPy not found – falling back to NumPy (CPU)
# Found 21 scan files:
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0000/DEPow_0.000000_rockinglayer_10x_00_converted.h5
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0001/DEPow_0.000000_rockinglayer_10x_01_converted.h5
#   /Users/edemdoehonu/Library/CloudStorage/GoogleDrive-edemdh@stanford.edu/My Drive/Morning_after_H5files/scan0002/DEPow_0.000000_rockinglayer_10x_02_converted.h5
# WARNING: Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py", line 683, in run_forever
#     self._run_once()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py", line 2050, in _run_once
#     handle._run()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel/kernelbase.py", line 448, in advance_eventloop
#     eventloop(self)
#   File "/Users/edemdoehonu/Library/Python/3.13/lib/python/site-packages/ipykernel/eventloops.py", line 145, in loop_qt
#     el.exec() if hasattr(el, "exec") else el.exec_()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/app_model/backends/qt/_qaction.py", line 59, in _on_triggered
#     self._app.commands.execute_command(self._command_id).result()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/app_model/registries/_commands_reg.py", line 242, in execute_command
#     future.set_result(cmd(*args, **kwargs))
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/in_n_out/_store.py", line 934, in _exec
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/in_n_out/_store.py", line 804, in _exec
#     result = func(**bound.arguments)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/_qapp_model/qactions/_file.py", line 49, in _close_app
#     window._qt_window.close(quit_app=True, confirm_need=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 509, in close
#     return super().close()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 298, in event
#     res = super().event(e)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 658, in closeEvent
#     quit_app_()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_event_loop.py", line 261, in quit_app
#     v.close()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/viewer.py", line 270, in close
#     self.layers.clear()
#   File "<frozen _collections_abc>", line 1141, in clear
#   File "<frozen _collections_abc>", line 1163, in pop
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/containers/_evented_list.py", line 188, in __delitem__
#     parent.events.removed(index=index, value=item)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 752, in __call__
#     self._invoke_callback(cb, event if pass_event else None)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 777, in _invoke_callback
#     cb(event)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/components/viewer_model.py", line 903, in _on_remove_layer
#     self._on_layers_change()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/components/viewer_model.py", line 669, in _on_layers_change
#     self.dims.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/components/dims.py", line 431, in reset
#     self.range = ((0, 2, 1),) * self.ndim
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/evented_model.py", line 308, in __setattr__
#     with ComparisonDelayer(self):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/evented_model.py", line 521, in __exit__
#     self._target._check_if_values_changed_and_emit_if_needed()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/evented_model.py", line 346, in _check_if_values_changed_and_emit_if_needed
#     getattr(self.events, name)(value=new_value)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 752, in __call__
#     self._invoke_callback(cb, event if pass_event else None)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 779, in _invoke_callback
#     cb()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_vispy/overlays/axes.py", line 45, in _on_data_change
#     self.node.set_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_vispy/visuals/axes.py", line 269, in set_data
#     self.line.set_data(data, color)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/visuals/line/line.py", line 189, in set_data
#     self.update()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/scene/node.py", line 331, in update
#     self.events.update()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#     ~~^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/visuals/visual.py", line 652, in _subv_update
#     self.update()
#     ~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/scene/node.py", line 334, in update
#     c.update(node=self)
#     ~~~~~~~~^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/scene/canvas.py", line 202, in update
#     super(SceneCanvas, self).update()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/app/canvas.py", line 448, in update
#     self._backend._vispy_update()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vispy/app/backends/_qt.py", line 480, in _vispy_update
#     self.update()
#     ~~~~~~~~~~~^^
# RuntimeError: wrapped C/C++ object of type CanvasBackendDesktop has been deleted
# ERROR: Invoking <bound method CompoundVisual._subv_update of <Axes at 0x13160b9d0>> for Event
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 779, in _invoke_callback
#     cb()
#     ~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_viewer.py", line 833, in _update_welcome_screen
#     self._welcome_widget.set_welcome_visible(not self.viewer.layers)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/widgets/qt_welcome.py", line 218, in set_welcome_visible
#     self.setCurrentIndex(int(visible))
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# RuntimeError: wrapped C/C++ object of type QtWidgetOverlay has been deleted
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 658, in closeEvent
#     quit_app_()
#     ~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_event_loop.py", line 261, in quit_app
#     v.close()
#     ~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/viewer.py", line 270, in close
#     self.layers.clear()
#     ~~~~~~~~~~~~~~~~~^^
#   File "<frozen _collections_abc>", line 1141, in clear
#   File "<frozen _collections_abc>", line 1163, in pop
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/containers/_evented_list.py", line 188, in __delitem__
#     parent.events.removed(index=index, value=item)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 752, in __call__
#     self._invoke_callback(cb, event if pass_event else None)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 788, in _invoke_callback
#     self.disconnect(cb)
#     ~~~~~~~~~~~~~~~^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/event.py", line 586, in disconnect
#     if callback in self._callbacks:
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/events/evented_model.py", line 469, in __eq__
#     if not isinstance(other, EventedModel):
#            ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pydantic/v1/main.py", line 310, in __instancecheck__
#     return hasattr(instance, '__post_root_validators__') and super().__instancecheck__(instance)
#            ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: wrapped C/C++ object of type QtViewer has been deleted
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 658, in closeEvent
#     quit_app_()
#     ~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_event_loop.py", line 261, in quit_app
#     v.close()
#     ~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/viewer.py", line 272, in close
#     self.window.close()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/qt_main_window.py", line 1914, in close
#     self._qt_viewer.close()
#     ~~~~~~~~~~~~~~~~~~~~~^^
# RuntimeError: wrapped C/C++ object of type QtViewer has been deleted
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/_qt/threads/status_checker.py:126, in StatusChecker.calculate_status(self=<napari._qt.threads.status_checker.StatusChecker object>)
#     122     return
#     124 try:
#     125     # Calculate the status change from cursor's movement
# --> 126     res = viewer._calc_status_from_cursor()
#         viewer = Viewer(camera=Camera(center=(np.float64(50.0), np.float64(161.925), np.float64(191.925)), zoom=np.float64(1.714453125), angles=(np.float64(-78.34826665400831), np.float64(-51.55700347134654), np.float64(-1.7032856900128794)), perspective=0.0, mouse_pan=True, mouse_zoom=True, orientation=(<DepthAxisOrientation.TOWARDS: 'towards'>, <VerticalAxisOrientation.DOWN: 'down'>, <HorizontalAxisOrientation.RIGHT: 'right'>)), cursor=Cursor(position=(np.float64(-3.7170417287426076), np.float64(224.07973669988385), np.float64(143.8750245930111)), viewbox=(0, 0), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=np.float64(0.0), stop=np.float64(100.0), step=np.float64(5.0)), RangeTuple(start=np.float64(0.0), stop=np.float64(323.84999999999997), step=np.float64(0.15)), RangeTuple(start=np.float64(0.0), stop=np.float64(383.84999999999997), step=np.float64(0.15))), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(np.float64(70.0), np.float64(161.85), np.float64(191.85)), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False, spacing=0.0), layers=[<Image layer 'intensity' at 0x38ae220d0>], help='use <2> for transform', status={'layer_name': 'intensity', 'layer_base': 'intensity', 'source_type': '', 'plugin': '', 'coordinates': ' [-1 223 151]: 2.04', 'coords': ' [-1 223 151]', 'value': '2.04'}, tooltip=Tooltip(visible=False, text=''), theme='dark', title='DFXM volume (χ, φ)', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[<function drag_to_zoom at 0x16332ade0>], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x16332ad40>], mouse_wheel_callbacks=[<function dims_scroll at 0x16332aca0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})    127 except Exception as e:  # pragma: no cover # noqa: BLE001
#     128     # Our codebase is not threadsafe. It is possible that an
#     129     # ViewerModel or Layer state is changed while we are trying to
#    (...)    132     # from crashing the thread. The exception is logged
#     133     # and a notification is sent.
#     134     notification_manager.dispatch(Notification.from_exception(e))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/components/viewer_model.py:732, in ViewerModel._calc_status_from_cursor(self=Viewer(camera=Camera(center=(np.float64(50.0), n...use_drag_gen={}, _mouse_wheel_gen={}, _keymap={}))
#     729 # If there is an active layer and a single selection, calculate status using "the classic way".
#     730 # Then return the status and the tooltip.
#     731 if active is not None and active._loaded and len(selection) < 2:
# --> 732     status = active.get_status(
#         active = <Image layer 'intensity' at 0x38ae220d0>
#         self = Viewer(camera=Camera(center=(np.float64(50.0), np.float64(161.925), np.float64(191.925)), zoom=np.float64(1.714453125), angles=(np.float64(-78.34826665400831), np.float64(-51.55700347134654), np.float64(-1.7032856900128794)), perspective=0.0, mouse_pan=True, mouse_zoom=True, orientation=(<DepthAxisOrientation.TOWARDS: 'towards'>, <VerticalAxisOrientation.DOWN: 'down'>, <HorizontalAxisOrientation.RIGHT: 'right'>)), cursor=Cursor(position=(np.float64(-3.7170417287426076), np.float64(224.07973669988385), np.float64(143.8750245930111)), viewbox=(0, 0), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=np.float64(0.0), stop=np.float64(100.0), step=np.float64(5.0)), RangeTuple(start=np.float64(0.0), stop=np.float64(323.84999999999997), step=np.float64(0.15)), RangeTuple(start=np.float64(0.0), stop=np.float64(383.84999999999997), step=np.float64(0.15))), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(np.float64(70.0), np.float64(161.85), np.float64(191.85)), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False, spacing=0.0), layers=[<Image layer 'intensity' at 0x38ae220d0>], help='use <2> for transform', status={'layer_name': 'intensity', 'layer_base': 'intensity', 'source_type': '', 'plugin': '', 'coordinates': ' [-1 223 151]: 2.04', 'coords': ' [-1 223 151]', 'value': '2.04'}, tooltip=Tooltip(visible=False, text=''), theme='dark', title='DFXM volume (χ, φ)', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[<function drag_to_zoom at 0x16332ade0>], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x16332ad40>], mouse_wheel_callbacks=[<function dims_scroll at 0x16332aca0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#         self.cursor.position = (np.float64(-3.7170417287426076), np.float64(224.07973669988385), np.float64(143.8750245930111))
#         self.cursor = Cursor(position=(np.float64(-3.7170417287426076), np.float64(224.07973669988385), np.float64(143.8750245930111)), viewbox=(0, 0), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0)
#         self.cursor._view_direction = array([0.01848, 0.62146, 0.78323])
#         self.dims = Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=np.float64(0.0), stop=np.float64(100.0), step=np.float64(5.0)), RangeTuple(start=np.float64(0.0), stop=np.float64(323.84999999999997), step=np.float64(0.15)), RangeTuple(start=np.float64(0.0), stop=np.float64(383.84999999999997), step=np.float64(0.15))), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(np.float64(70.0), np.float64(161.85), np.float64(191.85)), last_used=0)    733         self.cursor.position,
#     734         view_direction=self.cursor._view_direction,
#     735         dims_displayed=list(self.dims.displayed),
#     736         world=True,
#     737     )
#     738     return status, tooltip_text
#     740 # Otherwise, return the layer status of multiple selected layers
#     741 # or gridded layers as well as the tooltip.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/layers/base/base.py:2174, in Layer.get_status(self=<Image layer 'intensity'>, position=array([ -3.71704, 224.07974, 143.87502]), view_direction=array([0.01848, 0.62146, 0.78323]), dims_displayed=[0, 1, 2], world=True, value=None)
#    2172 if position is not None:
#    2173     position = np.asarray(position)
# -> 2174     value = self.get_value(
#         value = None
#         self = <Image layer 'intensity' at 0x38ae220d0>
#         position = array([ -3.71704, 224.07974, 143.87502])
#         view_direction = array([0.01848, 0.62146, 0.78323])
#         dims_displayed = [0, 1, 2]
#         world = True   2175         position,
#    2176         view_direction=view_direction,
#    2177         dims_displayed=dims_displayed,
#    2178         world=world,
#    2179     )
#    2180     coords_str, value_str = generate_layer_status_strings(
#    2181         position[-self.ndim :],
#    2182         value,
#    2183     )
#    2184 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/layers/base/base.py:1383, in Layer.get_value(self=<Image layer 'intensity'>, position=array([-7.43408e-01,  1.49386e+03,  9.59167e+02]), view_direction=array([5.54501e-04, 6.21567e-01, 7.83361e-01]), dims_displayed=[np.int64(0), np.int64(1), np.int64(2)], world=True)
#    1381     else:  # if len(dims_displayed) == 3:
#    1382         view_direction = self._world_to_data_ray(view_direction)
# -> 1383         start_point, end_point = self.get_ray_intersections(
#         self = <Image layer 'intensity' at 0x38ae220d0>
#         position = array([-7.43408e-01,  1.49386e+03,  9.59167e+02])
#         view_direction = array([5.54501e-04, 6.21567e-01, 7.83361e-01])
#         dims_displayed = [np.int64(0), np.int64(1), np.int64(2)]   1384             position=position,
#    1385             view_direction=view_direction,
#    1386             dims_displayed=dims_displayed,
#    1387             world=False,
#    1388         )
#    1389         value = self._get_value_3d(
#    1390             start_point=start_point,
#    1391             end_point=end_point,
#    1392             dims_displayed=dims_displayed,
#    1393         )
#    1394 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/layers/base/base.py:1901, in Layer.get_ray_intersections(self=<Image layer 'intensity'>, position=array([-7.43408e-01,  1.49386e+03,  9.59167e+02]), view_direction=array([5.54501e-04, 6.21567e-01, 7.83361e-01]), dims_displayed=[np.int64(0), np.int64(1), np.int64(2)], world=False)
#    1898 # bounding box is with upper limit excluded in the uses below
#    1899 bounding_box[:, 1] += 1
# -> 1901 start_point, end_point = self._get_ray_intersections(
#         self = <Image layer 'intensity' at 0x38ae220d0>
#         position = array([-7.43408e-01,  1.49386e+03,  9.59167e+02])
#         view_direction = array([5.54501e-04, 6.21567e-01, 7.83361e-01])
#         dims_displayed = [np.int64(0), np.int64(1), np.int64(2)]
#         world = False
#         bounding_box = array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]])   1902     position=position,
#    1903     view_direction=view_direction,
#    1904     dims_displayed=dims_displayed,
#    1905     world=world,
#    1906     bounding_box=bounding_box,
#    1907 )
#    1908 return start_point, end_point
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/layers/base/base.py:1981, in Layer._get_ray_intersections(self=<Image layer 'intensity'>, position=array([-2.43408e-01,  1.49436e+03,  9.59667e+02]), view_direction=array([5.54501e-04, 6.21567e-01, 7.83361e-01]), dims_displayed=[np.int64(0), np.int64(1), np.int64(2)], bounding_box=array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]]), world=False)
#    1977     return None, None
#    1979 # Calculate ray-bounding box face intersections
#    1980 start_point_displayed_dimensions = (
# -> 1981     intersect_line_with_axis_aligned_bounding_box_3d(
#         view_dir = array([5.54501e-04, 6.21567e-01, 7.83361e-01])
#         click_pos_data = array([-2.43408e-01,  1.49436e+03,  9.59667e+02])
#         front_face_normal = None
#         bounding_box = array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]])   1982         click_pos_data, view_dir, bounding_box, front_face_normal
#    1983     )
#    1984 )
#    1985 end_point_displayed_dimensions = (
#    1986     intersect_line_with_axis_aligned_bounding_box_3d(
#    1987         click_pos_data, view_dir, bounding_box, back_face_normal
#    1988     )
#    1989 )
#    1991 # add the coordinates for the axes not displayed
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/geometry.py:737, in intersect_line_with_axis_aligned_bounding_box_3d(line_point=array([-2.43408e-01,  1.49436e+03,  9.59667e+02]), line_direction=array([5.54501e-04, 6.21567e-01, 7.83361e-01]), bounding_box=array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]]), face_normal=None)
#     707 def intersect_line_with_axis_aligned_bounding_box_3d(
#     708     line_point: np.ndarray,
#     709     line_direction: np.ndarray,
#     710     bounding_box: np.ndarray,
#     711     face_normal: np.ndarray,
#     712 ):
#     713     """Find the intersection of a ray with the specified face of an
#     714     axis-aligned bounding box.
#     715
#    (...)    735         the specified face.
#     736     """
# --> 737     front_face_coordinate = face_coordinate_from_bounding_box(
#         bounding_box = array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]])
#         face_normal = None    738         bounding_box, face_normal
#     739     )
#     740     intersection_point = np.squeeze(
#     741         intersect_line_with_axis_aligned_plane(
#     742             front_face_coordinate,
#    (...)    746         )
#     747     )
#     749     return intersection_point
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/napari/utils/geometry.py:239, in face_coordinate_from_bounding_box(bounding_box=array([[   0.,   21.],
#        [   0., 2160.],
#        [   0., 2560.]]), face_normal=None)
#     218 """Get the coordinate for a given face in an axis-aligned bounding box.
#     219 For example, if the bounding box has extents [[0, 10], [0, 20], [0, 30]]
#     220 (ordered zyx), then the face with normal [0, 1, 0] is described by
#    (...)    236     the axis its normal is aligned with.
#     237 """
#     238 axis = np.argwhere(face_normal)
# --> 239 if face_normal[axis] > 0:
#         axis = array([], shape=(0, 0), dtype=int64)
#         face_normal = None    240     # face is pointing in the positive direction,
#     241     # take the max extent
#     242     face_coordinate = bounding_box[axis, 1]
#     243 else:
#     244     # face is pointing in the negative direction,
#     245     # take the min extent
#
# TypeError: 'NoneType' object is not subscriptable
